# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows',500)
# energy= pd.ExcelFile("EnergyIndicators.xls")
# energy.sheet_names
# df= energy.parse('Energy')
# df
xslx_frame= pd.read_excel('EnergyIndicators.xls')
xslx_frame
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8           NaN                                                NaN
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11          NaN                                                NaN
# 12          NaN                                                NaN
# ...

# %%
xslx_frame= xslx_frame[:-38]
xslx_frame
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8           NaN                                                NaN
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11          NaN                                                NaN
# 12          NaN                                                NaN
# ...

# %%
xslx_frame= pd.read_excel('EnergyIndicators.xls', skiprows=8,header=1 )
xslx_frame= xslx_frame[:-38]
xslx_frame.drop(xslx_frame.columns[[0,1]], axis=1, inplace=True)
xslx_frame.drop(xslx_frame.index[[0,2,3,4,5,6,7]], axis=0, inplace=True)
xslx_frame= xslx_frame.reset_index()
xslx_frame.drop(xslx_frame.columns[[0]], axis=1, inplace=True)
xslx_frame= xslx_frame.rename(columns={'Renewable Electricity Production':'% Renewable'})
# xslx_frame[['Energy Supply','Energy Supply per capita']].replace('...',np.nan)
xslx_frame=xslx_frame.replace('...',np.nan)
xslx_frame['Energy Supply']=xslx_frame['Energy Supply']*1000000
xslx_frame
# Out:
#                                                Country  Energy Supply  \
# 0                                              Andorra   9.000000e+06
# 1                                          Afghanistan   3.210000e+08
# 2                                              Albania   1.020000e+08
# 3                                              Algeria   1.959000e+09
# 4                                       American Samoa            NaN
# 5                                              Andorra   9.000000e+06
# 6                                               Angola   6.420000e+08
# 7                                             Anguilla   2.000000e+06
# 8                                  Antigua and Barbuda   8.000000e+06
# 9                                            Argentina   3.378000e+09
# 10                                             Armenia   1.430000e+08
# 11                                               Aruba   1.200000e+07
# ...

# %%
# xslx_frame['Country']= xslx_frame['Country'].replace({"Republic of Korea": "South Korea",
# "United States of America": "United States",
# "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
# "China, Hong Kong Special Administrative Region": "Hong Kong"},inplace=True)

xslx_frame['Country']= xslx_frame['Country'].str.replace("United Kingdom of Great Britain and Northern Ireland","United Kingdom")
xslx_frame
# Out:
#                                              Country  Energy Supply  \
# 0                                            Andorra   9.000000e+06
# 1                                        Afghanistan   3.210000e+08
# 2                                            Albania   1.020000e+08
# 3                                            Algeria   1.959000e+09
# 4                                     American Samoa            NaN
# 5                                            Andorra   9.000000e+06
# 6                                             Angola   6.420000e+08
# 7                                           Anguilla   2.000000e+06
# 8                                Antigua and Barbuda   8.000000e+06
# 9                                          Argentina   3.378000e+09
# 10                                           Armenia   1.430000e+08
# 11                                             Aruba   1.200000e+07
# 12                                        Australia1   5.386000e+09
# ...

# %%
replacement={'Country':{r'Republic of Korea': 'South Korea',
r'United States of America': 'United States',
r'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
r'China, Hong Kong Special Administrative Region': 'Hong Kong'}}

xslx_frame.replace(replacement, regex=True, inplace=True)

xslx_frame
# Out:
#                                          Country  Energy Supply  \
# 0                                        Andorra   9.000000e+06
# 1                                    Afghanistan   3.210000e+08
# 2                                        Albania   1.020000e+08
# 3                                        Algeria   1.959000e+09
# 4                                 American Samoa            NaN
# 5                                        Andorra   9.000000e+06
# 6                                         Angola   6.420000e+08
# 7                                       Anguilla   2.000000e+06
# 8                            Antigua and Barbuda   8.000000e+06
# 9                                      Argentina   3.378000e+09
# 10                                       Armenia   1.430000e+08
# 11                                         Aruba   1.200000e+07
# 12                                    Australia1   5.386000e+09
# 13                                       Austria   1.391000e+09
# ...

# %%
cname= xslx_frame['Country'].str.split(' \(')
xslx_frame['Country']= cname.str[0]
xslx_frame
# Out:
#                                          Country  Energy Supply  \
# 0                                        Andorra   9.000000e+06
# 1                                    Afghanistan   3.210000e+08
# 2                                        Albania   1.020000e+08
# 3                                        Algeria   1.959000e+09
# 4                                 American Samoa            NaN
# 5                                        Andorra   9.000000e+06
# 6                                         Angola   6.420000e+08
# 7                                       Anguilla   2.000000e+06
# 8                            Antigua and Barbuda   8.000000e+06
# 9                                      Argentina   3.378000e+09
# 10                                       Armenia   1.430000e+08
# 11                                         Aruba   1.200000e+07
# 12                                    Australia1   5.386000e+09
# 13                                       Austria   1.391000e+09
# ...

# %%
xslx_frame['Country']= xslx_frame['Country'].map(lambda x:x.rstrip('1234567890'))
# xslx_frame['Country']=xslx_frame['Country'].replace(regex=True, inplace=True, to_replace=r'\W+', value=r'')
xslx_frame
# Out:
#                                         Country  Energy Supply  \
# 0                                       Andorra   9.000000e+06
# 1                                   Afghanistan   3.210000e+08
# 2                                       Albania   1.020000e+08
# 3                                       Algeria   1.959000e+09
# 4                                American Samoa            NaN
# 5                                       Andorra   9.000000e+06
# 6                                        Angola   6.420000e+08
# 7                                      Anguilla   2.000000e+06
# 8                           Antigua and Barbuda   8.000000e+06
# 9                                     Argentina   3.378000e+09
# 10                                      Armenia   1.430000e+08
# 11                                        Aruba   1.200000e+07
# 12                                    Australia   5.386000e+09
# 13                                      Austria   1.391000e+09
# ...

# %%
import pandas as pd
import numpy as np

GDP= pd.read_csv('world_bank.csv', skiprows=3, header=1)
GDP
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                              Andorra          AND
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
replacement= {'Country Name':{r'Korea, Rep.': 'South Korea', 
r"Iran, Islamic Rep.": "Iran",
r'Hong Kong SAR, China': 'Hong Kong'}}
GDP.replace(replacement, regex=True, inplace= True)
GDP= GDP.rename(columns={'Country Name':'Country'})
GDP
# Out:
#                                                Country Country Code  \
# 0                                                Aruba          ABW
# 1                                              Andorra          AND
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
import pandas as pd
import numpy as np

ScimEn= pd.read_excel('scimagojr-3.xlsx')
ScimEn= ScimEn.rename(columns={'Country Name': 'Country'})
ScimEn
# Out:
#      Rank                         Country  Documents  Citable documents  \
# 0       1                           China     127050             126767
# 1       2                   United States      96661              94747
# 2       3                           Japan      30504              30287
# 3       4                  United Kingdom      20944              20357
# 4       5              Russian Federation      18534              18301
# 5       6                          Canada      17899              17620
# 6       7                         Germany      17027              16831
# 7       8                           India      15005              14841
# 8       9                          France      13153              12973
# 9      10                     South Korea      11983              11923
# 10     11                           Italy      10964              10794
# 11     12                           Spain       9428               9330
# ...

# %%
import functools as fnt
# xcopy= xslx_frame.copy()
# gdpc= GDP.copy()
# sc= ScimEn.copy()
# xcopy= xcopy.set_index('Country')
# xcopy
# gdpc= gdpc.set_index('Country')
# gdpc
# sc= sc.set_index('Country')
# sc
dfs= [xslx_frame, GDP, ScimEn]

# dfs= [xcopy, gdpc, sc]

# df_final= pd.merge(xcopy,gdpc, how='outer', left_index=True, right_index=True)
# df_final
df_final= fnt.reduce(lambda left, right: pd.merge(left, right, how='inner', left_on='Country', right_on='Country'), dfs)
df_final
# Out:
#                     Country  Energy Supply  Energy Supply per capita  \
# 0                   Andorra   9.000000e+06                     121.0
# 1                   Andorra   9.000000e+06                     121.0
# 2               Afghanistan   3.210000e+08                      10.0
# 3                   Albania   1.020000e+08                      35.0
# 4                   Algeria   1.959000e+09                      51.0
# 5            American Samoa            NaN                       NaN
# 6                    Angola   6.420000e+08                      27.0
# 7       Antigua and Barbuda   8.000000e+06                      84.0
# 8                 Argentina   3.378000e+09                      79.0
# 9                   Armenia   1.430000e+08                      48.0
# 10                Australia   5.386000e+09                     231.0
# 11                  Austria   1.391000e+09                     164.0
# 12               Azerbaijan   5.670000e+08                      60.0
# ...

# %%
df_final = df_final.set_index('Country')
df_final= df_final[['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
count_before= df_final['Rank'].count()
df_final= df_final[df_final['Rank'] < 16]
count_after= df_final['Rank'].count()
print(count_before - count_after)
df_final
# Out:
# 148
#                     Rank  Documents  Citable documents  Citations  \
# Country
# Australia             14       8831               8725      90765
# Brazil                15       8668               8596      60702
# Canada                 6      17899              17620     215003
# China                  1     127050             126767     597237
# France                 9      13153              12973     130632
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# Iran                  13       8896               8819      57470
# Italy                 11      10964              10794     111850
# Japan                  3      30504              30287     223024
# South Korea           10      11983              11923     114675
# Russian Federation     5      18534              18301      34266
# Spain                 12       9428               9330     123336
# ...

# %%
import pandas as pd
import numpy as np
import functools as fnt

xslx_frame= pd.read_excel('EnergyIndicators.xls', skiprows=8,header=1 )
xslx_frame= xslx_frame[:-38]
xslx_frame.drop(xslx_frame.columns[[0,1]], axis=1, inplace=True)
xslx_frame.drop(xslx_frame.index[[0,2,3,4,5,6,7]], axis=0, inplace=True)
xslx_frame= xslx_frame.reset_index()
xslx_frame.drop(xslx_frame.columns[[0]], axis=1, inplace=True)
xslx_frame= xslx_frame.rename(columns={'Renewable Electricity Production':'% Renewable'})
# xslx_frame[['Energy Supply','Energy Supply per capita']].replace('...',np.nan)
xslx_frame=xslx_frame.replace('...',np.nan)
xslx_frame['Energy Supply']=xslx_frame['Energy Supply']*1000000
replacement={'Country':{r'Republic of Korea': 'South Korea',
    r'United States of America': 'United States',
    r'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
    r'China, Hong Kong Special Administrative Region': 'Hong Kong'}}
xslx_frame.replace(replacement, regex=True, inplace=True)
cname= xslx_frame['Country'].str.split(' \(')
xslx_frame['Country']= cname.str[0]
xslx_frame['Country']= xslx_frame['Country'].map(lambda x:x.rstrip('1234567890'))
GDP= pd.read_csv('world_bank.csv', skiprows=3, header=1)
replacement= {'Country Name':{r'Korea, Rep.': 'South Korea', 
    r"Iran, Islamic Rep.": "Iran",
    r'Hong Kong SAR, China': 'Hong Kong'}}
GDP.replace(replacement, regex=True, inplace= True)
GDP= GDP.rename(columns={'Country Name':'Country'})
ScimEn= pd.read_excel('scimagojr-3.xlsx')
ScimEn= ScimEn.rename(columns={'Country Name': 'Country'})
dfs= [xslx_frame, GDP, ScimEn]
df_final= fnt.reduce(lambda left, right: pd.merge(left, right, how='inner', left_on='Country', right_on='Country'), dfs)
df_final = df_final.set_index('Country')

def answer_one():
#     global df_final # to use global df_final and not to confuse python intepreter with local we have to tell it explicitily that df_final is gloabal one that we are using
    # otherwise it is always wise to create new local variable inside the function
    df_final1= df_final[['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
    df_final1= df_final1[df_final['Rank'] < 16]
    return df_final1

answer_one()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# Australia             14       8831               8725      90765
# Brazil                15       8668               8596      60702
# Canada                 6      17899              17620     215003
# China                  1     127050             126767     597237
# France                 9      13153              12973     130632
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# Iran                  13       8896               8819      57470
# Italy                 11      10964              10794     111850
# Japan                  3      30504              30287     223024
# South Korea           10      11983              11923     114675
# Russian Federation     5      18534              18301      34266
# Spain                 12       9428               9330     123336
# ...

# %%
df_final
count_before= df_final['Rank'].count()
df_final1= df_final[df_final['Rank'] < 16]
count_after= df_final1['Rank'].count()
type((count_before - count_after).tolist())
# Out:
# int
